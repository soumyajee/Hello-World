# %%
import pandas as pd 
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale

# %%
wine_data=pd.read_csv('winequality-red.csv')
wine_data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_data = wine_data.iloc[:,:]
wine_data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_normal = scale(wine_data)

# %%
wine_normal
# Out:
# array([[-0.52835961,  0.96187667, -1.39147228, ..., -0.57920652,
#         -0.96024611, -0.78782264],
#        [-0.29854743,  1.96744245, -1.39147228, ...,  0.1289504 ,
#         -0.58477711, -0.78782264],
#        [-0.29854743,  1.29706527, -1.18607043, ..., -0.04808883,
#         -0.58477711, -0.78782264],
#        ...,
#        [-1.1603431 , -0.09955388, -0.72391627, ...,  0.54204194,
#          0.54162988,  0.45084835],
#        [-1.39015528,  0.65462046, -0.77526673, ...,  0.30598963,
#         -0.20930812, -0.78782264],
#        [-1.33270223, -1.21684919,  1.02199944, ...,  0.01092425,
#          0.54162988,  0.45084835]])

# %%
pca = PCA(n_components = 10)
pca_values = pca.fit_transform(wine_normal)
pca_values
# Out:
# array([[-1.77944158,  1.15730315, -1.38658056, ...,  0.04031995,
#         -0.2944202 ,  0.07311218],
#        [-1.00418467,  2.07183784,  0.00775877, ..., -0.17671393,
#          0.58734197, -0.56573584],
#        [-0.91578319,  1.3934342 , -0.69928641, ..., -0.08868663,
#          0.5464948 , -0.16206469],
#        ...,
#        [-1.36626511, -0.51756099,  1.25069637, ..., -0.12115434,
#         -0.10756917, -0.7528537 ],
#        [-2.36714672,  0.70354479,  0.89948219, ...,  0.60740021,
#         -0.37829801, -0.72345329],
#        [-0.28877628, -1.24084585,  1.21809517, ..., -0.11542162,
#          0.16519356,  0.30587722]])

# %%
pca.components_
# Out:
# array([[ 0.48788336, -0.26512898,  0.47333547,  0.13915442,  0.19742679,
#         -0.04588071,  0.00406675,  0.37030119, -0.43272085,  0.25453535,
#         -0.07317678,  0.11248878],
#        [-0.00417321,  0.33896786, -0.1373581 ,  0.16773634,  0.18978819,
#          0.25948314,  0.36397137,  0.33078079, -0.06544015, -0.10933362,
#         -0.50270865, -0.47316621],
#        [-0.16482854, -0.22708884,  0.10022856,  0.24362014, -0.02660785,
#          0.61611132,  0.54073214, -0.16872267,  0.06977056,  0.21291324,
#          0.22497138,  0.22336929],
#        [-0.23109808,  0.04185824, -0.0567358 , -0.38303758,  0.65477782,
#         -0.03371148, -0.02845973, -0.20069341, -0.00546618,  0.56050237,
#         -0.09170143, -0.03666923],
#        [-0.07877938,  0.29937933, -0.12014871,  0.70936319,  0.26623723,
#         -0.15941286, -0.21845284,  0.20879298,  0.25764682,  0.21483493,
#          0.25972635,  0.13758414],
# ...

# %%
var = pca.explained_variance_ratio_
var
# Out:
# array([0.26009731, 0.1868235 , 0.14024331, 0.10125174, 0.0811053 ,
#        0.05521602, 0.05152648, 0.04215605, 0.03427563, 0.02732662])

# %%
var1 = np.cumsum(np.round(var,decimals = 4)*100)
var1
# Out:
# array([26.01, 44.69, 58.71, 68.84, 76.95, 82.47, 87.62, 91.84, 95.27,
#        98.  ])

# %%
plt.plot(var1,color="red")

# %%
 pca_values[:,4:7]
# Out:
# array([[ 0.23388451, -0.97698268, -0.11052758],
#        [ 0.18245388,  0.65777472, -1.37678974],
#        [ 0.0952097 ,  0.25482297, -0.72033805],
#        ...,
#        [ 0.19591558, -0.55216207, -0.19603884],
#        [ 0.02137974, -0.80575252,  0.12666899],
#        [ 0.23112056, -0.20292493,  1.44341443]])

# %%
finalDf = pd.concat([pd.DataFrame(pca_values[:,4:8],columns=['pc1','pc2','pc3','pc4']), wine_data[['quality']]], axis = 1)
finalDf
# Out:
#            pc1       pc2       pc3       pc4  quality
# 0     0.233885 -0.976983 -0.110528  0.040320        5
# 1     0.182454  0.657775 -1.376790 -0.176714        5
# 2     0.095210  0.254823 -0.720338 -0.088687        5
# 3    -1.524742 -0.132218  0.200660 -0.202816        6
# 4     0.233885 -0.976983 -0.110528  0.040320        5
# ...        ...       ...       ...       ...      ...
# 1594 -0.312981  0.130820  0.291926  0.137412        5
# 1595  0.104124 -0.751228 -0.436849  0.181539        6
# 1596  0.195916 -0.552162 -0.196039 -0.121154        6
# 1597  0.021380 -0.805753  0.126669  0.607400        5
# 1598  0.231121 -0.202925  1.443414 -0.115422        6
#
# [1599 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
import seaborn as sns
sns.scatterplot(data=finalDf,x='pc1',y='pc2',hue='quality',s = 100)

# %%
import seaborn as sns
sns.scatterplot(data=finalDf,x='pc3',y='pc4',hue='quality',s = 100)
